# %%
#BeautifulSoup is used for webscraping
from urllib.request import urlopen
html=urlopen('https://www.hubertiming.com/results/2018MLK')
html

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(html)
title=soup.title
print(title.text)
# Out:
# 2018 MLK Dream Run 5K Race Results

# %%
data=[]
allrows=soup.find_all('tr')
for row in allrows:
    allcols=row.find_all('td')
    #print(allcols)
    datarow=[]
    for col in allcols:
        datarow.append(col.text)
    data.append(datarow)
print(data[5:])
# Out:
# [['1', '1191', 'MAX RANDOLPH', 'M', '29', 'WASHINGTON', 'DC', '16:48', '5:25', '1 of 78', 'M 21-39', '1 of 33', '0:08', '16:56'], ['2', '1080', 'NEED NAME KAISER RUNNER', 'M', '25', 'PORTLAND', 'OR', '17:31', '5:39', '2 of 78', 'M 21-39', '2 of 33', '0:09', '17:40'], ['3', '1275', 'DAN FRANEK', 'M', '52', 'PORTLAND', 'OR', '18:15', '5:53', '3 of 78', 'M 40-54', '1 of 27', '0:07', '18:22'], ['4', '1223', 'PAUL TAYLOR', 'M', '54', 'PORTLAND', 'OR', '18:31', '5:58', '4 of 78', 'M 40-54', '2 of 27', '0:07', '18:38'], ['5', '1245', 'THEO KINMAN', 'M', '22', '', '', '19:31', '6:17', '5 of 78', 'M 21-39', '3 of 33', '0:09', '19:40'], ['6', '1185', 'MELISSA GIRGIS', 'F', '27', 'PORTLAND', 'OR', '19:39', '6:20', '1 of 113', 'F 21-39', '1 of 53', '0:07', '19:46'], ['7', '1251', 'CHARLIE COGGESHALL', 'M', '39', 'PORTLAND', 'OR', '19:51', '6:24', '6 of 78', 'M 21-39', '4 of 33', '0:10', '20:01'], ['8', '1154', 'UNKNOWN RUNNER SEE TIMER', 'M', '', '', '', '24:58', '8:03', '7 of 78', '', '1 of 9',
# ...

# %%
import pandas as pd
dataframe=pd.DataFrame(data[5:])
dataframe
# Out:
#       0     1                         2  3   4            5   6        7   \
# 0      1  1191              MAX RANDOLPH  M  29   WASHINGTON  DC    16:48
# 1      2  1080   NEED NAME KAISER RUNNER  M  25     PORTLAND  OR    17:31
# 2      3  1275                DAN FRANEK  M  52     PORTLAND  OR    18:15
# 3      4  1223               PAUL TAYLOR  M  54     PORTLAND  OR    18:31
# 4      5  1245               THEO KINMAN  M  22                     19:31
# 5      6  1185            MELISSA GIRGIS  F  27     PORTLAND  OR    19:39
# 6      7  1251        CHARLIE COGGESHALL  M  39     PORTLAND  OR    19:51
# 7      8  1154  UNKNOWN RUNNER SEE TIMER  M                         24:58
# 8      9  1163  UNKNOWN RUNNER SEE TIMER  M                         25:01
# 9     10  1242            KIMONTI WILSON  F  48                     25:01
# 10    11  1017             COREY MCMANUS  M  37    BEAVERTON  OR    25:17
# 11    12  1112          MITCHELL JOHNSON  M  25     PORTLAND  OR    25:31
# ...

# %%
#Logic to get the column names
column=[]
header=soup.find_all('th')
for h in header:
    column.append(h.text)
column
dataframe.columns=column
dataframe
# Out:
#     Place   Bib                      Name Gender Age         City State  \
# 0       1  1191              MAX RANDOLPH      M  29   WASHINGTON    DC
# 1       2  1080   NEED NAME KAISER RUNNER      M  25     PORTLAND    OR
# 2       3  1275                DAN FRANEK      M  52     PORTLAND    OR
# 3       4  1223               PAUL TAYLOR      M  54     PORTLAND    OR
# 4       5  1245               THEO KINMAN      M  22
# 5       6  1185            MELISSA GIRGIS      F  27     PORTLAND    OR
# 6       7  1251        CHARLIE COGGESHALL      M  39     PORTLAND    OR
# 7       8  1154  UNKNOWN RUNNER SEE TIMER      M
# 8       9  1163  UNKNOWN RUNNER SEE TIMER      M
# 9      10  1242            KIMONTI WILSON      F  48
# 10     11  1017             COREY MCMANUS      M  37    BEAVERTON    OR
# 11     12  1112          MITCHELL JOHNSON      M  25     PORTLAND    OR
# 12     13  1062                 ALEX KABA      M  36     PORTLAND    OR
# ...
